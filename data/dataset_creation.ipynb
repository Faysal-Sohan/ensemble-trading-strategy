# %%
import sys
import os
root_dir = os.getcwd()
sys.path.insert(1, root_dir)
sys.path.append('../modules/')
import pandas as pd
import numpy as np
import ensemble_trading_strategy as ets

# %% [markdown]
# ## Assets used in our Model

# %%
stock_tickers = [
    "AAPL", "ABT", "ADBE", "AEP", "AES", "AFL", "ALGN", "AMD", "AMT", "AOS",
    "APA", "APD", "ARE", "AWK", "AXON", "BA", "BAC", "BAX", "BDX", "BG",
    "BKR", "BRK-B", "BX", "BXP", "CAT", "CCI", "CDNS", "CE", "CEG", "COF",
    "CPB", "CPT", "DIS", "EA", "FMC", "FOX", "GOOGL", "IFF", "KLAC", "LNT",
    "MMM", "MO", "NVDA", "STZ", "TECH", "TRGP", "VLO", "WBD", "WMB", "WMT"
    ]

# %% [markdown]
# ## Combining all Assets featured data into a single DataFrame

# %%
combined_X = pd.DataFrame()
combined_y = pd.Series()
for ticker in stock_tickers:
    stock_df = pd.read_csv(f'../data/S & P 50/{ticker}.csv')
    stock_df = ets.add_features(stock_df)
    y = ets.get_target_signal_rets(stock_df)
    # stock_df['Ticker'] = ticker  # Add a column to identify the stock
    combined_X = pd.concat([combined_X, stock_df])
    combined_y = pd.concat([combined_y, y])
# Out:
# /tmp/ipykernel_11632/4212520915.py:9: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   combined_y = pd.concat([combined_y, y])

# %%
combined_X.tail(10)
# Out:
#                   open        high         low       close      volume  \
# date
# 2022-12-16  144.479996  144.720001  142.570007  142.750000  13447700.0
# 2022-12-19  143.009995  143.559998  141.729996  142.800003   5022500.0
# 2022-12-20  142.919998  144.639999  142.250000  144.050003   5669800.0
# 2022-12-21  144.320007  145.940002  144.259995  145.179993   4575500.0
# 2022-12-22  144.770004  144.979996  141.929993  143.479996   4360800.0
# 2022-12-23  143.050003  143.800003  142.279999  143.770004   3182500.0
# 2022-12-27  144.039993  144.449997  143.190002  143.809998   3348200.0
# 2022-12-28  143.470001  143.669998  140.910004  141.289993   5082100.0
# 2022-12-29  142.139999  143.020004  141.750000  142.149994   3057300.0
# 2022-12-30  141.559998  141.990005  140.809998  141.789993   3835300.0
#
#                  sma_5      sma_10       ema_5      ema_10  MACD_12_26_9  ...  \
# date                                                                      ...
# ...

# %%
combined_X.shape
# Out:
# (59882, 28)

# %%
combined_y.shape
# Out:
# (59882,)

# %%
combined_X.isna().sum()
# Out:
# open                   0
# high                   0
# low                    0
# close                  0
# volume                 0
# sma_5                  0
# sma_10                 0
# ema_5                  0
# ema_10                 0
# MACD_12_26_9           0
# MACDh_12_26_9          0
# MACDs_12_26_9          0
# ADX_14                 0
# DMP_14                 0
# DMN_14                 0
# rsi_14                 0
# BBL_5_2.0              0
# BBM_5_2.0              0
# BBU_5_2.0              0
# BBB_5_2.0              0
# BBP_5_2.0              0
# cci_16                 0
# atr                    0
# STOCHk_14_3_3          0
# STOCHd_14_3_3          0
# STOCHRSIk_16_14_3_3    0
# STOCHRSId_16_14_3_3    0
# wpr                    0
# dtype: int64

# %% [markdown]
# ## Saving the data

# %%
combined_X.to_csv('../data/dataset/combined_stocks_data_X.csv',index=False)

# %%
combined_y.to_csv('../data/dataset/combined_stocks_data_y.csv',index=False)
